# %%
import symqups as sq
import sympy as sp
import time
import matplotlib as mpl

# %%
sq.get_random_poly
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sq.get_random_poly
#
# AttributeError: module 'symqups' has no attribute 'get_random_poly'
