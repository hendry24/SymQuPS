# %%
from symqups.simple import *
import sympy as sp
import symqups as sq
import time
import matplotlib as mpl
from IPython.display import display

# %%
N = 5
x = get_random_poly([aOp, adOp], min_pow=N, max_pow=N, n_terms=1) * rho * get_random_poly([aOp, adOp], min_pow=N, max_pow=N, n_terms=1)
display(x)

start = time.time()
len(CGTransform(x).doit().expand().args)
# time.time()-start
# Out:
# \hat{a}^{\dagger}_{}**4*\hat{a}_{}*\rho_{}*\hat{a}^{\dagger}_{}*\hat{a}_{}**3*\hat{a}^{\dagger}_{}
# 495

# %%
iCGTransform(a*sp.Function("f")(a, ad))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/pyvenv/lib/python3.12/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      71 try:
# ---> 72     retval = cfunc(*args, **kwargs)
#      73 except TypeError as e:
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# SympifyError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 iCGTransform(a*sp.Function("f")(a, ad))
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py:29, in preprocess_func.<locals>.wrapper(*args, **kwargs)
#      23 # HACK: The multiprocessing implementation has an issue
#      24 # where the first call in a session involving objects
#      25 # defined within that session will raise a Pickling error
#      26 # that does not occur when we call the second time.
#      28 try:
# ---> 29     return func(*sympified_args, **sympified_kwargs)
#      30 except PicklingError:
#      31     return func(*sympified_args, **sympified_kwargs)
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/cg.py:343, in iCGTransform.__new__(cls, expr, lazy, *_vars)
#     340     return super(iCGTransform, cls).__new__(cls, A, *_vars)
#     342 expr = qp2alpha(sp.sympify(expr.doit().expand()))
# --> 343 return operation_routine(expr,
#     344                         iCGTransform,
#     345                         [],
#     346                         [HilbertSpaceObject],
#     347                         {(PhaseSpaceVariable, StateFunction) : expr},
#     348                         {sp.Add : treat_add,
#     349                          sp.Derivative : treat_der,
#     350                          sp.Pow : treat_pow,
#     351                          sp.Mul : treat_mul,
#     352                          PhaseSpaceVariable : lambda A: sc2op(A),
#     353                          StateFunction : rho/(pi.val)**get_N(),
#     354                          sp.Function : treat_foo,
#     355                          CGTransform : lambda A: A.args[0],
#     356                          Star : treat_Star}
#     357                         )
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py:119, in operation_routine(expr, name, screen_types, deep_screen_types, return_if_expr_does_not_have, return_if_expr_is)
#     117     if isinstance(expr, if_is):
#     118         if callable(then_return):
# --> 119             return then_return(expr)
#     120         return then_return
#     122 invalid_input(expr, name)
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/cg.py:329, in iCGTransform.__new__.<locals>.treat_mul(A)
#     317             factors = [sp.binomial(m,j),
#     318                        sp.binomial(n,k),
#     319                        k1**(j+k),
#    (...)
#     325                        ad**j
#     326                        ]
#     327             out_summands.append(sp.Mul(*coefs, *factors))
# --> 329 return sp.Add(out_summands)
#
# File ~/pyvenv/lib/python3.12/site-packages/sympy/core/cache.py:76, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      74     if not e.args or not e.args[0].startswith('unhashable type:'):
#      75         raise
# ---> 76     retval = func(*args, **kwargs)
#      77 return retval
#
# File ~/pyvenv/lib/python3.12/site-packages/sympy/core/operations.py:57, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      52 @cacheit
#      53 def __new__(cls, *args, evaluate=None, _sympify=True):
#      54     # Allow faster processing by passing ``_sympify=False``, if all arguments
#      55     # are already sympified.
#      56     if _sympify:
# ---> 57         args = list(map(_sympify_, args))
#      59     # Disallow non-Expr args in Add/Mul
#      60     typ = cls._args_type
#
# File ~/pyvenv/lib/python3.12/site-packages/sympy/core/sympify.py:514, in _sympify(a)
#     488 def _sympify(a):
#     489     """
#     490     Short version of :func:`~.sympify` for internal usage for ``__add__`` and
#     491     ``__eq__`` methods where it is ok to allow some things (like Python
#    (...)
#     512
#     513     """
# --> 514     return sympify(a, strict=True)
#
# File ~/pyvenv/lib/python3.12/site-packages/sympy/core/sympify.py:454, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     451         return sympify(int(a))
#     453 if strict:
# --> 454     raise SympifyError(a)
#     456 if iterable(a):
#     457     try:
#
# SympifyError: SympifyError: [(s/2 + 1/2)*\hat{a}_{}*sOrdering(f(\hat{a}_{}, \hat{a}^{\dagger}_{}), s), (1/2 - s/2)*sOrdering(f(\hat{a}_{}, \hat{a}^{\dagger}_{}), s)*\hat{a}_{}]
