# %%
from symqups.simple import *
import sympy as sp
import symqups as sq
import time
import matplotlib as mpl
from IPython.display import display

# %%
N = 5
x = get_random_poly([aOp, adOp], min_pow=N, max_pow=N, n_terms=1) * rho * get_random_poly([aOp, adOp], min_pow=N, max_pow=N, n_terms=1)
display(x)

start = time.time()
len(CGTransform(x).doit().expand().args)
# time.time()-start
# Out:
# \hat{a}^{\dagger}_{}**2*\hat{a}_{}*\hat{a}^{\dagger}_{}*\hat{a}_{}*\rho_{}*\hat{a}^{\dagger}_{}*\hat{a}_{}**3*\hat{a}^{\dagger}_{}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 display(x)
#       5 start = time.time()
# ----> 6 len(CGTransform(x).doit().expand().args)
#       7 # time.time()-start
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py:29, in preprocess_func.<locals>.wrapper(*args, **kwargs)
#      23 # HACK: The multiprocessing implementation has an issue
#      24 # where the first call in a session involving objects
#      25 # defined within that session will raise a Pickling error
#      26 # that does not occur when we call the second time.
#      28 try:
# ---> 29     return func(*sympified_args, **sympified_kwargs)
#      30 except PicklingError:
#      31     return func(*sympified_args, **sympified_kwargs)
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/cg.py:152, in CGTransform.__new__(cls, expr, *_vars)
#     149     return super(CGTransform, cls).__new__(cls, A, *_vars)
#     151 expr = qp2alpha(sp.sympify(expr).expand())
# --> 152 return operation_routine(expr,
#     153                         CGTransform,
#     154                         [],
#     155                         [PhaseSpaceObject],
#     156                         {(PhaseSpaceVariableOperator, densityOp) : expr},
#     157                         {sp.Add : treat_add,
#     158                          sp.Mul : treat_mul,
#     159                          sp.Function : treat_function,
#     160                          (PhaseSpaceVariableOperator, sp.Pow) : lambda A: op2sc(A),
#     161                          densityOp : (pi.val)**get_N() * W,
#     162                          sOrdering : treat_sOrdering,
#     163                          iCGTransform : lambda A: A.args[0],
#     164                          Commutator : treat_commutator,
#     165                          HattedStar : treat_HattedStar,
#     166                          sp.Derivative : treat_der}
#     167                         )
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py:119, in operation_routine(expr, name, screen_types, deep_screen_types, return_if_expr_does_not_have, return_if_expr_is)
#     117     if isinstance(expr, if_is):
#     118         if callable(then_return):
# --> 119             return then_return(expr)
#     120         return then_return
#     122 invalid_input(expr, name)
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/cg.py:99, in CGTransform.__new__.<locals>.treat_mul(A)
#      96     else:
#      97         coef_factors.append(arg)
# ---> 99 return sp.Mul(*coef_factors, Star(*out_star_factors))
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/star.py:231, in Star.__new__(cls, *args)
#     230 def __new__(cls, *args : sp.Expr):
# --> 231     return super().__new__(cls, *args, hatted=False)
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py:29, in preprocess_func.<locals>.wrapper(*args, **kwargs)
#      23 # HACK: The multiprocessing implementation has an issue
#      24 # where the first call in a session involving objects
#      25 # defined within that session will raise a Pickling error
#      26 # that does not occur when we call the second time.
#      28 try:
# ---> 29     return func(*sympified_args, **sympified_kwargs)
#      30 except PicklingError:
#      31     return func(*sympified_args, **sympified_kwargs)
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/star.py:201, in _StarTemplate.__new__(cls, hatted, *args)
#     199     if arg.has(qpType):
#     200         arg = qp2alpha(arg)
# --> 201     out = _star_base(out, arg, hatted)
#     202 except _CannotBoppFlag:
#     203     if out != 1:
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/star.py:179, in _star_base(F, G, hatted)
#     161 def treat_add(A : sp.Add):
#     162     return sp.Add(*mp_helper(A.args,
#     163                              functools.partial(bopp_monomial,
#     164                                                B=other,
#     165                                                left=left)
#     166                              )
#     167                   )
#     169 return operation_routine(Bopp_shifted,
#     170                          _StarTemplate,
#     171                          [],
#     172                          [],
#     173                          {},
#     174                          {sp.Add : treat_add,
#     175                           (sp.Mul,
#     176                            sp.Pow,
#     177                            var_group,
#     178                            state)
# --> 179                           : bopp_monomial(Bopp_shifted,
#     180                                           B=other,
#     181                                           left=left)
#     182                           }
#     183                          )
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/star.py:52, in _Star_Bopp_monomial_A_times_B(A, B, left)
#      49         coef_factors.append(arg)
#      51 bopped_series_summands = []
# ---> 52 for j_lst in itertools.product(*e_lst):
#      53     bopp_factors = []
#      54     der_wrt = []
#
# TypeError: 'Integer' object is not iterable

# %%
import itertools

list(itertools.product([1,2,3]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import itertools
# ----> 3 list(itertools.product(*[1,2,3]))
#
# TypeError: 'int' object is not iterable
