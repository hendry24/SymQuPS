# %%
from symqups.simple import *
import sympy as sp
import symqups as sq
import time
import matplotlib as mpl
from IPython.display import display

# %%
sOrdering(adOp*aOp).content
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sOrdering(adOp*aOp).content
#
# AttributeError: 'sOrdering' object has no attribute 'content'
