# %%
from symqups.simple import *
import sympy as sp
import time
import matplotlib as mpl
from IPython.display import display

# %%
N = 10
x = get_random_poly([aOp, adOp], min_pow=N, max_pow=N, n_terms=1)
display(x)

start = time.time()
CGTransform(x)
time.time()-start
# Out:
# \hat{a}_{}*\hat{a}^{\dagger}_{}**3*\hat{a}_{}*\hat{a}^{\dagger}_{}*\hat{a}_{}*\hat{a}^{\dagger}_{}*\hat{a}_{}*\hat{a}^{\dagger}_{}
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/multiprocessing.py", line 80, in pool_helper
#     return dill.dumps(foo(dill.loads(inpt_bytes)))
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
# ...
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 189, in __new__
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/cg.py", line 102, in treat_mul
#     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py", line 29, in wrapper
#     return func(*sympified_args, **sympified_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/manipulations.py", line 187, in normal_ordered_equivalent
#     return operation_routine(expr,
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py", line 119, in operation_routine
#     return then_return(expr)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/manipulations.py", line 181, in treat_mul
#     A_sep = separate_term_oper_by_sub(A)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/operator_handling.py", line 131, in separate_term_oper_by_sub
#     non_op, oper = separate_operator(expr)
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/symqups/_internal/operator_handling.py", line 66, in separate_operator
#     operator *= arg
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/sympy/core/numbers.py", line 1904, in __mul__
#     return Rational.__mul__(self, other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/sympy/core/decorators.py", line 65, in __sympifyit_wrapper
#     return func(a, b)
#            ^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/sympy/core/numbers.py", line 1468, in __mul__
#     return Number.__mul__(self, other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/sympy/core/decorators.py", line 65, in __sympifyit_wrapper
#     return func(a, b)
#            ^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/sympy/core/numbers.py", line 485, in __mul__
#     return AtomicExpr.__mul__(self, other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/sympy/core/decorators.py", line 236, in _func
#     return func(self, other)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/sympy/core/decorators.py", line 106, in binary_op_wrapper
#     return func(self, other)
#            ^^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/sympy/core/expr.py", line 219, in __mul__
#     return Mul(self, other)
#            ^^^^^^^^^^^^^^^^
#   File "/home/hendry/pyvenv/lib/python3.12/site-packages/sympy/core/cache.py", line 72, in wrapper
#     retval = cfunc(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
# """
#
# The above exception was the direct cause of the following exception:
#
# RecursionError                            Traceback (most recent call last)
# Cell In[5], line 6
#       3 display(x)
#       5 start = time.time()
# ----> 6 CGTransform(x)
#       7 time.time()-start
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py:29, in preprocess_func.<locals>.wrapper(*args, **kwargs)
#      23 # HACK: The multiprocessing implementation has an issue
#      24 # where the first call in a session involving objects
#      25 # defined within that session will raise a Pickling error
#      26 # that does not occur when we call the second time.
#      28 try:
# ---> 29     return func(*sympified_args, **sympified_kwargs)
#      30 except PicklingError:
#      31     return func(*sympified_args, **sympified_kwargs)
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/cg.py:189, in CGTransform.__new__(cls, expr, *_vars)
#     186     return super(CGTransform, cls).__new__(cls, A, *_vars)
#     188 expr = qp2alpha(sp.sympify(expr).doit().expand())
# --> 189 return operation_routine(expr,
#     190                         CGTransform,
#     191                         [],
#     192                         [PhaseSpaceObject],
#     193                         {(PhaseSpaceVariableOperator, densityOp) : expr},
#     194                         {sp.Add : treat_add,
#     195                          sp.Mul : treat_mul,
#     196                          sp.Function : treat_function,
#     197                          (PhaseSpaceVariableOperator, sp.Pow) : lambda A: op2sc(A),
#     198                          densityOp : (pi.val)**get_N() * W,
#     199                          sOrdering : treat_sOrdering,
#     200                          iCGTransform : lambda A: A.args[0],
#     201                          Commutator : lambda A: CGTransform(A.doit().expand()),
#     202                          HattedStar : treat_HattedStar,
#     203                          sp.Derivative : treat_der}
#     204                         )
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py:119, in operation_routine(expr, name, screen_types, deep_screen_types, return_if_expr_does_not_have, return_if_expr_is)
#     117     if isinstance(expr, if_is):
#     118         if callable(then_return):
# --> 119             return then_return(expr)
#     120         return then_return
#     122 invalid_input(expr, name)
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/cg.py:102, in CGTransform.__new__.<locals>.treat_mul(A)
#      99         nonpoly_idx.append(k)
#     101 if not(nonpoly_idx):
# --> 102     return CGTransform(express(sOrdering(normal_ordered_equivalent(A),1)))
#     104 ###
#     106 def apply_PBSO(mono, target, left):
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/_internal/preprocessing.py:29, in preprocess_func.<locals>.wrapper(*args, **kwargs)
#      23 # HACK: The multiprocessing implementation has an issue
#      24 # where the first call in a session involving objects
#      25 # defined within that session will raise a Pickling error
#      26 # that does not occur when we call the second time.
#      28 try:
# ---> 29     return func(*sympified_args, **sympified_kwargs)
#      30 except PicklingError:
#      31     return func(*sympified_args, **sympified_kwargs)
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/cg.py:189, in CGTransform.__new__(cls, expr, *_vars)
#     186     return super(CGTransform, cls).__new__(cls, A, *_vars)
#     188 expr = qp2alpha(sp.sympify(expr).doit().expand())
# --> 189 return operation_routine(expr,
#     190                         CGTransform,
#     191                         [],
#     192                         [PhaseSpaceObject],
#     193                         {(PhaseSpaceVariableOperator, densityOp) : expr},
#     194                         {sp.Add : treat_add,
#     195                          sp.Mul : treat_mul,
#     196                          sp.Function : treat_function,
#     197                          (PhaseSpaceVariableOperator, sp.Pow) : lambda A: op2sc(A),
#     198                          densityOp : (pi.val)**get_N() * W,
#     199                          sOrdering : treat_sOrdering,
#     200                          iCGTransform : lambda A: A.args[0],
#     201                          Commutator : lambda A: CGTransform(A.doit().expand()),
#     202                          HattedStar : treat_HattedStar,
#     203                          sp.Derivative : treat_der}
#     204                         )
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/_internal/basic_routines.py:119, in operation_routine(expr, name, screen_types, deep_screen_types, return_if_expr_does_not_have, return_if_expr_is)
#     117     if isinstance(expr, if_is):
#     118         if callable(then_return):
# --> 119             return then_return(expr)
#     120         return then_return
#     122 invalid_input(expr, name)
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/cg.py:77, in CGTransform.__new__.<locals>.treat_add(A)
#      76 def treat_add(A : sp.Expr) -> sp.Expr:
# ---> 77     return sp.Add(*mp_helper(A.args, CGTransform))
#
# File ~/pyvenv/lib/python3.12/site-packages/symqups/_internal/multiprocessing.py:61, in mp_helper(inpt_lst, foo)
#      59 _mp_is_running = True
#      60 with Pool(MP_CONFIG["num_cpus"]) as pool:
# ---> 61     res_byte_lst = pool.map(partial(pool_helper, foo=foo),
#      62                             [dill.dumps(inpt) for inpt in inpt_lst])
#      63 _mp_is_running = False
#      64 return [dill.loads(res_bytes) for res_bytes in res_byte_lst]
#
# File /usr/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /usr/lib/python3.12/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# RecursionError: maximum recursion depth exceeded
