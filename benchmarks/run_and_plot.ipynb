# %%
from symqups.simple import *
import sympy as sp
import time
import matplotlib as mpl
from IPython.display import display

# %%
N = 1
x = get_random_poly([aOp, adOp], min_pow=N, max_pow=N, n_terms=1)
display(x)

start = time.time()
# CGTransform(x)  
time.time()-start
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 N = 1
# ----> 2 x = get_random_poly([aOp, adOp], min_pow=N, max_pow=N, n_terms=1)
#       3 display(x)
#       5 start = time.time()
#
# NameError: name 'get_random_poly' is not defined

# %%
start = time.time()
CGTransform(express(sOrdering(normal_ordered_equivalent(x), 1), s.val))
time.time()-start
# Out:
# Process ForkPoolWorker-156:
# Process ForkPoolWorker-154:
# Process ForkPoolWorker-160:
# Process ForkPoolWorker-159:
# Process ForkPoolWorker-157:
# Process ForkPoolWorker-158:
# Process ForkPoolWorker-153:
# Process ForkPoolWorker-155:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# ...
