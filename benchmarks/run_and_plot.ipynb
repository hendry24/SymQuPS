# %%
from symqups.simple import *
import sympy as sp
import symqups as sq
import time
import matplotlib as mpl
from IPython.display import display

# %%
N = 20
x = get_random_poly([aOp, adOp], min_pow=N, max_pow=N, n_terms=1) * rho * get_random_poly([aOp, adOp], min_pow=N, max_pow=N, n_terms=1)
display(x)

start = time.time()
CGTransform(x)
time.time()-start
# Out:
# \hat{a}_{}*\rho_{}*\hat{a}_{}
# 0.002704620361328125

# %%
from symqups.manipulations import Commutator

Commutator(adOp, aOp).args[1].args
# Out:
# (\hat{a}_{}, \hat{a}^{\dagger}_{})
