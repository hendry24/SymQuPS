# %%
from symqups.simple import *
import sympy

# %%
CGTransform(aOp*rho)
Star(a, W)
s.val = 1
CGTransform(aOp*rho)
Star(a,W)
s.val = 0
CGTransform(aOp*rho)
# Out:
# yyyeah 1
# yyyeah 1
# yyyeah 1
# yyyeah 1
# yyyeah 0
# \alpha_{}*StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}) + Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \overline{\alpha}_{})/2

# %%
omega, lmbda, Gamma, n_mean = sympy.symbols(r"omega, lambda, Gamma, n_\mathrm{avg}")
H = hbar.val*omega*adOp*aOp + lmbda*adOp + dagger(lmbda*adOp)
dissip_1 = [2*Gamma*(1+n_mean), aOp]
dissip_2 = [2*Gamma*n_mean, adOp]
lme = LindbladMasterEquation(H, dissip_1, dissip_2)
result = collect_by_derivative(sympy.expand(CGTransform(lme)))
result
# print(sp.latex(result))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 omega, lmbda, Gamma, n_mean = sympy.symbols(r"omega, lambda, Gamma, n_\mathrm{avg}")
#       2 H = hbar.val*omega*adOp*aOp + lmbda*adOp + dagger(lmbda*adOp)
#       3 dissip_1 = [2*Gamma*(1+n_mean), aOp]
#       4 dissip_2 = [2*Gamma*n_mean, adOp]
#
# NameError: name 'sympy' is not defined

# %%
result.subs({Gamma : 0, lmbda : 0})
# print(sp.latex(result.subs({Gamma : 0, lmbda : 0})))
# Out:
# Eq(Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), t_{}), I*omega*\alpha_{}*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \alpha_{}) - I*omega*\overline{\alpha}_{}*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \overline{\alpha}_{}))

# %%
s.val=-1
result = collect_by_derivative(sympy.expand(CGTransform(lme))).subs(Gamma, 0)
result
# print(sp.latex(result.subs({Gamma : 0})))
# Out:
# Eq(Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), t_{}), (I*omega*\alpha_{} + I*lambda/hbar)*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \alpha_{}) + (-I*omega*\overline{\alpha}_{} - I*conjugate(lambda)/hbar)*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \overline{\alpha}_{}))

# %%
sympy.expand(CGTransform(lme))
# Out:
# Eq(Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), t_{}), 2*Gamma*n_\mathrm{avg}*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \alpha_{}, \overline{\alpha}_{}) + Gamma*s*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \alpha_{}, \overline{\alpha}_{}) + Gamma*\alpha_{}*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \alpha_{}) + Gamma*\overline{\alpha}_{}*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \overline{\alpha}_{}) + Gamma*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \alpha_{}, \overline{\alpha}_{}) + 2*Gamma*StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}) + I*omega*\alpha_{}*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \alpha_{}) - I*omega*\overline{\alpha}_{}*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \overline{\alpha}_{}) + I*lambda*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \alpha_{})/hbar - I*conjugate(lambda)*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \overline{\alpha}_{})/hbar)

# %%
s.val = 1
result.subs({omega : 0, lmbda:0})
# print(sp.latex(result.subs({omega : 0, lmbda:0})))
# s.val=s.default_value
# Out:
# Eq(Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), t_{}), Gamma*\alpha_{}*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \alpha_{}) + Gamma*\overline{\alpha}_{}*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \overline{\alpha}_{}) + 2*Gamma*StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}) + (2*Gamma*n_\mathrm{avg} + Gamma*s + Gamma)*Derivative(StateFunction(t_{}, \alpha_{}, \overline{\alpha}_{}), \alpha_{}, \overline{\alpha}_{}))
